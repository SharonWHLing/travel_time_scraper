# %%
# https://medium.com/analytics-vidhya/turn-right-in-2-miles-finding-distances-using-the-google-maps-api-and-pandas-fef8554f0b7d
# https://www.geeksforgeeks.org/python-calculate-distance-duration-two-places-using-google-distance-matrix-api/

# setup packages and API key

! pip install pendulum
! pip install Jupyter-Beeper # https://pypi.org/project/Jupyter-Beeper/

# from googlemaps import Client as GoogleMaps # this if you're using the googlemaps package
import requests, json
import pandas as pd 
import time
import pendulum
import jupyter_beeper

b = jupyter_beeper.Beeper()

api_key = #######

print ("Done!")

#reset current working directory

import os
path = os.getcwd()
print(path) #get current working directory

os.chdir(r"C:\Users\XXXXX\Desktop")
path = os.getcwd()
print(path) #reset current working directory

# %%
#FULL REPOSITORY OF DEPARTURE TIMES

dt = 1614078000 #dt_1 = Tuesday, Feb 23, 2021 6:00:00 AM local time, according to https://www.epochconverter.com/
dt = 1614079800 #dt_2 = Tuesday, Feb 23, 2021 6:30:00 AM local time, according to https://www.epochconverter.com/
dt = 1614081600 #dt_3 = Tuesday, Feb 23, 2021 7:00:00 AM local time, according to https://www.epochconverter.com/
dt = 1614083400 #dt_4 = Tuesday, Feb 23, 2021 7:30:00 AM local time, according to https://www.epochconverter.com/
dt = 1614085200 #dt_5 = Tuesday, Feb 23, 2021 8:00:00 AM local time, according to https://www.epochconverter.com/
dt = 1614087000 #dt_6 = Tuesday, Feb 23, 2021 8:30:00 AM local time, according to https://www.epochconverter.com/
dt = 1614088800 #dt_7 = Tuesday, Feb 23, 2021 9:00:00 AM local time, according to https://www.epochconverter.com/

dt = 1614110400 #dt_8 = Tuesday, Feb 23, 2021 3:00:00 PM local time, according to https://www.epochconverter.com/
dt = 1614112200 #dt_9 = Tuesday, Feb 23, 2021 3:30:00 PM local time, according to https://www.epochconverter.com/
dt = 1614114000 #dt_10 = Tuesday, Feb 23, 2021 4:00:00 PM local time, according to https://www.epochconverter.com/
dt = 1614115800 #dt_11 = Tuesday, Feb 23, 2021 4:30:00 PM local time, according to https://www.epochconverter.com/
dt = 1614117600 #dt_12 = Tuesday, Feb 23, 2021 5:00:00 PM local time, according to https://www.epochconverter.com/
dt = 1614119400 #dt_13 = Tuesday, Feb 23, 2021 5:30:00 PM local time, according to https://www.epochconverter.com/
dt = 1614121200 #dt_14 = Tuesday, Feb 23, 2021 6:00:00 PM local time, according to https://www.epochconverter.com/

# %%
## FOR DRIVING ONLY

#read data and set parameters
addresses = pd.read_csv("XXXX.csv")
addresses.head()

list = []
for ind in range(1,15):
    a = str('dep_time_') + str(ind)
    list.append(a)
    a = str('drive_arr_time_') + str(ind)
    list.append(a)
    a = str('drive_dis_') + str(ind)
    list.append(a)
    a = str('drive_dur_') + str(ind)
    list.append(a)
    a = str('drive_dur_in_traffic_') + str(ind)
    list.append(a)
    a = str('drive_notes_') + str(ind)
    list.append(a)

for l in list:
    addresses[l] = ""
    
##############################################################
#for morning commute via driving

for x in range(len(addresses)):
    
    time.sleep(1) #to add delay in case of large DFs
    print("Calculating for Entry", x+1 , "@", str(addresses['FULL ADDRESS'][x]))
    print()
    
    start = str(addresses['lat'][x]) + "," + str(addresses['long'][x]) 
    end = 'XX.XXXXXX,-XX.XXXXXX' # INSERT COORDINATES OF END DESTINATION
      
    #dt 1, driving
    print("Calculating... Driving @ DT1!")
    
    try:
          
        dt = 1614078000 #dt_1 = Tuesday, Feb 23, 2021 6:00:00 AM local time, according to https://www.epochconverter.com/
    
        url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
        url = str(url) + 'mode=driving' + '&origins=' + str(start) + '&destinations=' + str(end) + '&units=imperial' + '&traffic_model=pessimistic' + '&departure_time=' + str(dt) + '&key=' + str(api_key)
        r = requests.get(url)
        data = r.json()
        print(url)        
        
        addresses['dep_time_1'][x] = str(pendulum.from_timestamp(dt))
        addresses['drive_arr_time_1'][x] = str(pendulum.from_timestamp((dt) + (data['rows'][0]['elements'][0]['duration']['value'])))
        addresses['drive_dis_1'][x] = data['rows'][0]['elements'][0]['distance']['text']
        addresses['drive_dur_1'][x] = data['rows'][0]['elements'][0]['duration']['text']
        addresses['drive_dur_in_traffic_1'][x] = data['rows'][0]['elements'][0]['duration_in_traffic']['text']       

    except Exception as e:
        addresses['drive_notes_1'][x] = "Unexpected error occurred."
        print("Unexpected error occurred.", e )
        b.beep() # beep once for errors

    # save results, reopen file
    addresses.to_csv('testing_results.csv', index=False)
    addresses = pd.read_csv("testing_results.csv")
        
    #dt 2, driving 
    print("Calculating... Driving @ DT2!")
        
    try: 

        dt = 1614079800 #dt_2 = Tuesday, Feb 23, 2021 6:30:00 AM local time, according to https://www.epochconverter.com/
        
        url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
        url = str(url) + 'mode=driving' + '&origins=' + str(start) + '&destinations=' + str(end) + '&units=imperial' + '&traffic_model=pessimistic' + '&departure_time=' + str(dt) + '&key=' + str(api_key)
        r = requests.get(url)
        data = r.json()
        print(url)           
        
        addresses['dep_time_2'][x] = str(pendulum.from_timestamp(dt))
        addresses['drive_arr_time_2'][x] = str(pendulum.from_timestamp((dt) + (data['rows'][0]['elements'][0]['duration']['value'])))
        addresses['drive_dis_2'][x] = data['rows'][0]['elements'][0]['distance']['text']
        addresses['drive_dur_2'][x] = data['rows'][0]['elements'][0]['duration']['text']
        addresses['drive_dur_in_traffic_2'][x] = data['rows'][0]['elements'][0]['duration_in_traffic']['text']       
        
    except Exception as e:
        addresses['drive_notes_2'][x] = "Unexpected error occurred."
        print("Unexpected error occurred.", e )
        b.beep() # beep once for errors
    
    # save results, reopen file
    addresses.to_csv('testing_results.csv', index=False)
    addresses = pd.read_csv("testing_results.csv")
    
    #dt 3, driving
    print("Calculating... Driving @ DT3!")

    try:     
        dt = 1614081600 #dt_3 = Tuesday, Feb 23, 2021 7:00:00 AM local time, according to https://www.epochconverter.com/

        url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
        url = str(url) + 'mode=driving' + '&origins=' + str(start) + '&destinations=' + str(end) + '&units=imperial' + '&traffic_model=pessimistic' + '&departure_time=' + str(dt) + '&key=' + str(api_key)
        r = requests.get(url)
        data = r.json()
        print(url)           
        
        addresses['dep_time_3'][x] = str(pendulum.from_timestamp(dt))
        addresses['drive_arr_time_3'][x] = str(pendulum.from_timestamp((dt) + (data['rows'][0]['elements'][0]['duration']['value'])))
        addresses['drive_dis_3'][x] = data['rows'][0]['elements'][0]['distance']['text']
        addresses['drive_dur_3'][x] = data['rows'][0]['elements'][0]['duration']['text']
        addresses['drive_dur_in_traffic_3'][x] = data['rows'][0]['elements'][0]['duration_in_traffic']['text']       
        
    except Exception as e:
        addresses['drive_notes_3'][x] = "Unexpected error occurred."
        print("Unexpected error occurred.", e )
        b.beep() # beep once for errors 

    # save results, reopen file
    addresses.to_csv('testing_results.csv', index=False)
    addresses = pd.read_csv("testing_results.csv")
        
    #dt 4, driving
    print("Calculating... Driving @ DT4!")

    try:
        dt = 1614083400 #dt_4 = Tuesday, Feb 23, 2021 7:30:00 AM local time, according to https://www.epochconverter.com/
        
        url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
        url = str(url) + 'mode=driving' + '&origins=' + str(start) + '&destinations=' + str(end) + '&units=imperial' + '&traffic_model=pessimistic' + '&departure_time=' + str(dt) + '&key=' + str(api_key)
        r = requests.get(url)
        data = r.json()
        print(url)          
        
        addresses['dep_time_4'][x] = str(pendulum.from_timestamp(dt))
        addresses['drive_arr_time_4'][x] = str(pendulum.from_timestamp((dt) + (data['rows'][0]['elements'][0]['duration']['value'])))
        addresses['drive_dis_4'][x] = data['rows'][0]['elements'][0]['distance']['text']
        addresses['drive_dur_4'][x] = data['rows'][0]['elements'][0]['duration']['text']
        addresses['drive_dur_in_traffic_4'][x] = data['rows'][0]['elements'][0]['duration_in_traffic']['text']       
        
    except Exception as e:
        addresses['drive_notes_4'][x] = "Unexpected error occurred."
        print("Unexpected error occurred.", e )
        b.beep() # beep once for errors
    
    # save results, reopen file
    addresses.to_csv('testing_results.csv', index=False)
    addresses = pd.read_csv("testing_results.csv")
    
    #dt 5, driving
    print("Calculating... Driving @ DT5!")    
    
    try: 
        dt = 1614085200 #dt_5 = Tuesday, Feb 23, 2021 8:00:00 AM local time, according to https://www.epochconverter.com/  
        
        url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
        url = str(url) + 'mode=driving' + '&origins=' + str(start) + '&destinations=' + str(end) + '&units=imperial' + '&traffic_model=pessimistic' + '&departure_time=' + str(dt) + '&key=' + str(api_key)
        r = requests.get(url)
        data = r.json()
        print(url)          
        
        addresses['dep_time_5'][x] = str(pendulum.from_timestamp(dt))
        addresses['drive_arr_time_5'][x] = str(pendulum.from_timestamp((dt) + (data['rows'][0]['elements'][0]['duration']['value'])))
        addresses['drive_dis_5'][x] = data['rows'][0]['elements'][0]['distance']['text']
        addresses['drive_dur_5'][x] = data['rows'][0]['elements'][0]['duration']['text']
        addresses['drive_dur_in_traffic_5'][x] = data['rows'][0]['elements'][0]['duration_in_traffic']['text']       
        
    except Exception as e:
        addresses['drive_notes_5'][x] = "Unexpected error occurred."
        print("Unexpected error occurred.", e )
        b.beep() # beep once for errors
    
    # save results, reopen file
    addresses.to_csv('testing_results.csv', index=False)
    addresses = pd.read_csv("testing_results.csv")   
     
    #dt 6, driving
    print("Calculating... Driving @ DT6!") 
        
    try:
        dt = 1614087000 #dt_6 = Tuesday, Feb 23, 2021 8:30:00 AM local time, according to https://www.epochconverter.com/
        
        url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
        url = str(url) + 'mode=driving' + '&origins=' + str(start) + '&destinations=' + str(end) + '&units=imperial' + '&traffic_model=pessimistic' + '&departure_time=' + str(dt) + '&key=' + str(api_key)
        r = requests.get(url)
        data = r.json()
        print(url)          
        
        addresses['dep_time_6'][x] = str(pendulum.from_timestamp(dt))
        addresses['drive_arr_time_6'][x] = str(pendulum.from_timestamp((dt) + (data['rows'][0]['elements'][0]['duration']['value'])))
        addresses['drive_dis_6'][x] = data['rows'][0]['elements'][0]['distance']['text']
        addresses['drive_dur_6'][x] = data['rows'][0]['elements'][0]['duration']['text']
        addresses['drive_dur_in_traffic_6'][x] = data['rows'][0]['elements'][0]['duration_in_traffic']['text']       
        
    except Exception as e:
        addresses['drive_notes_6'][x] = "Unexpected error occurred."
        print("Unexpected error occurred.", e )
        b.beep() # beep once for errors        

    #dt 7, driving
    print("Calculating... Driving @ DT7!")

    try:
        dt = 1614088800 #dt_7 = Tuesday, Feb 23, 2021 9:00:00 AM local time, according to https://www.epochconverter.com/

        url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
        url = str(url) + 'mode=driving' + '&origins=' + str(start) + '&destinations=' + str(end) + '&units=imperial' + '&traffic_model=pessimistic' + '&departure_time=' + str(dt) + '&key=' + str(api_key)
        r = requests.get(url)
        data = r.json()
        print(url)          
        
        addresses['dep_time_7'][x] = str(pendulum.from_timestamp(dt))
        addresses['drive_arr_time_7'][x] = str(pendulum.from_timestamp((dt) + (data['rows'][0]['elements'][0]['duration']['value'])))
        addresses['drive_dis_7'][x] = data['rows'][0]['elements'][0]['distance']['text']
        addresses['drive_dur_7'][x] = data['rows'][0]['elements'][0]['duration']['text']
        addresses['drive_dur_in_traffic_7'][x] = data['rows'][0]['elements'][0]['duration_in_traffic']['text']       
        
    except Exception as e:
        addresses['drive_notes_7'][x] = "Unexpected error occurred."
        print("Unexpected error occurred.", e )
        b.beep() # beep once for errors        

    addresses.to_csv('testing_results.csv', index=False)
    addresses = pd.read_csv("testing_results.csv")

    print("...Calculated!")
    print()  
    
##############################################################
    
#for evening commute via driving

for x in range(len(addresses)):
    
    time.sleep(1) #to add delay in case of large DFs
    print("Calculating for Entry", x+1 , "@", str(addresses['FULL ADDRESS'][x]))
    print()
    
    start = '33.769763,-84.397204' # Coca-Cola HQ coordinates @ 541 Luckie St NW, Atlanta, GA 30313
    end = str(addresses['lat'][x]) + "," + str(addresses['long'][x]) 
      
    #dt 8, driving
    print("Calculating... Driving @ DT8!")

    try:
          
        dt = 1614110400 #dt_8 = Tuesday, Feb 23, 2021 3:00:00 PM local time, according to https://www.epochconverter.com/    
        
        url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
        url = str(url) + 'mode=driving' + '&origins=' + str(start) + '&destinations=' + str(end) + '&units=imperial' + '&traffic_model=pessimistic' + '&departure_time=' + str(dt) + '&key=' + str(api_key)
        r = requests.get(url)
        data = r.json()
        print(url)        
        
        addresses['dep_time_8'][x] = str(pendulum.from_timestamp(dt))
        addresses['drive_arr_time_8'][x] = str(pendulum.from_timestamp((dt) + (data['rows'][0]['elements'][0]['duration']['value'])))
        addresses['drive_dis_8'][x] = data['rows'][0]['elements'][0]['distance']['text']
        addresses['drive_dur_8'][x] = data['rows'][0]['elements'][0]['duration']['text']
        addresses['drive_dur_in_traffic_8'][x] = data['rows'][0]['elements'][0]['duration_in_traffic']['text']       

    except Exception as e:
        addresses['drive_notes_8'][x] = "Unexpected error occurred."
        print("Unexpected error occurred.", e )
        b.beep() # beep once for errors

    # save results, reopen file
    addresses.to_csv('testing_results.csv', index=False)
    addresses = pd.read_csv("testing_results.csv")
    
    #dt 9, driving
    print("Calculating... Driving @ DT9!")

    try:
          
        dt = 1614112200 #dt_9 = Tuesday, Feb 23, 2021 3:30:00 PM local time, according to https://www.epochconverter.com/
        
        url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
        url = str(url) + 'mode=driving' + '&origins=' + str(start) + '&destinations=' + str(end) + '&units=imperial' + '&traffic_model=pessimistic' + '&departure_time=' + str(dt) + '&key=' + str(api_key)
        r = requests.get(url)
        data = r.json()
        print(url)        
        
        addresses['dep_time_9'][x] = str(pendulum.from_timestamp(dt))
        addresses['drive_arr_time_9'][x] = str(pendulum.from_timestamp((dt) + (data['rows'][0]['elements'][0]['duration']['value'])))
        addresses['drive_dis_9'][x] = data['rows'][0]['elements'][0]['distance']['text']
        addresses['drive_dur_9'][x] = data['rows'][0]['elements'][0]['duration']['text']
        addresses['drive_dur_in_traffic_9'][x] = data['rows'][0]['elements'][0]['duration_in_traffic']['text']       

    except Exception as e:
        addresses['drive_notes_9'][x] = "Unexpected error occurred."
        print("Unexpected error occurred.", e )
        b.beep() # beep once for errors

    # save results, reopen file
    addresses.to_csv('testing_results.csv', index=False)
    addresses = pd.read_csv("testing_results.csv")
    
    #dt 10, driving
    print("Calculating... Driving @ DT10!")

    try:
          
        dt = 1614114000 #dt_10 = Tuesday, Feb 23, 2021 4:00:00 PM local time, according to https://www.epochconverter.com/
        
        url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
        url = str(url) + 'mode=driving' + '&origins=' + str(start) + '&destinations=' + str(end) + '&units=imperial' + '&traffic_model=pessimistic' + '&departure_time=' + str(dt) + '&key=' + str(api_key)
        r = requests.get(url)
        data = r.json()
        print(url)        
        
        addresses['dep_time_10'][x] = str(pendulum.from_timestamp(dt))
        addresses['drive_arr_time_10'][x] = str(pendulum.from_timestamp((dt) + (data['rows'][0]['elements'][0]['duration']['value'])))
        addresses['drive_dis_10'][x] = data['rows'][0]['elements'][0]['distance']['text']
        addresses['drive_dur_10'][x] = data['rows'][0]['elements'][0]['duration']['text']
        addresses['drive_dur_in_traffic_10'][x] = data['rows'][0]['elements'][0]['duration_in_traffic']['text']       

    except Exception as e:
        addresses['drive_notes_10'][x] = "Unexpected error occurred."
        print("Unexpected error occurred.", e )
        b.beep() # beep once for errors

    # save results, reopen file
    addresses.to_csv('testing_results.csv', index=False)
    addresses = pd.read_csv("testing_results.csv")  
    
    #dt 11, driving
    print("Calculating... Driving @ DT11!")

    try:
          
        dt = 1614115800 #dt_11 = Tuesday, Feb 23, 2021 4:30:00 PM local time, according to https://www.epochconverter.com/
        
        url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
        url = str(url) + 'mode=driving' + '&origins=' + str(start) + '&destinations=' + str(end) + '&units=imperial' + '&traffic_model=pessimistic' + '&departure_time=' + str(dt) + '&key=' + str(api_key)
        r = requests.get(url)
        data = r.json()
        print(url)        
        
        addresses['dep_time_11'][x] = str(pendulum.from_timestamp(dt))
        addresses['drive_arr_time_11'][x] = str(pendulum.from_timestamp((dt) + (data['rows'][0]['elements'][0]['duration']['value'])))
        addresses['drive_dis_11'][x] = data['rows'][0]['elements'][0]['distance']['text']
        addresses['drive_dur_11'][x] = data['rows'][0]['elements'][0]['duration']['text']
        addresses['drive_dur_in_traffic_11'][x] = data['rows'][0]['elements'][0]['duration_in_traffic']['text']       

    except Exception as e:
        addresses['drive_notes_11'][x] = "Unexpected error occurred."
        print("Unexpected error occurred.", e )
        b.beep() # beep once for errors

    # save results, reopen file
    addresses.to_csv('testing_results.csv', index=False)
    addresses = pd.read_csv("testing_results.csv")    

    #dt 12, driving
    print("Calculating... Driving @ DT12!")

    try:
          
        dt = 1614117600 #dt_12 = Tuesday, Feb 23, 2021 5:00:00 PM local time, according to https://www.epochconverter.com/        
        url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
        url = str(url) + 'mode=driving' + '&origins=' + str(start) + '&destinations=' + str(end) + '&units=imperial' + '&traffic_model=pessimistic' + '&departure_time=' + str(dt) + '&key=' + str(api_key)
        r = requests.get(url)
        data = r.json()
        print(url)        
        
        addresses['dep_time_12'][x] = str(pendulum.from_timestamp(dt))
        addresses['drive_arr_time_12'][x] = str(pendulum.from_timestamp((dt) + (data['rows'][0]['elements'][0]['duration']['value'])))
        addresses['drive_dis_12'][x] = data['rows'][0]['elements'][0]['distance']['text']
        addresses['drive_dur_12'][x] = data['rows'][0]['elements'][0]['duration']['text']
        addresses['drive_dur_in_traffic_12'][x] = data['rows'][0]['elements'][0]['duration_in_traffic']['text']       

    except Exception as e:
        addresses['drive_notes_12'][x] = "Unexpected error occurred."
        print("Unexpected error occurred.", e )
        b.beep() # beep once for errors

    # save results, reopen file
    addresses.to_csv('testing_results.csv', index=False)
    addresses = pd.read_csv("testing_results.csv")    

    #dt 13, driving
    print("Calculating... Driving @ DT13!")

    try:
          
        dt = 1614119400 #dt_13 = Tuesday, Feb 23, 2021 5:30:00 PM local time, according to https://www.epochconverter.com/
        url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
        url = str(url) + 'mode=driving' + '&origins=' + str(start) + '&destinations=' + str(end) + '&units=imperial' + '&traffic_model=pessimistic' + '&departure_time=' + str(dt) + '&key=' + str(api_key)
        r = requests.get(url)
        data = r.json()
        print(url)        
        
        addresses['dep_time_13'][x] = str(pendulum.from_timestamp(dt))
        addresses['drive_arr_time_13'][x] = str(pendulum.from_timestamp((dt) + (data['rows'][0]['elements'][0]['duration']['value'])))
        addresses['drive_dis_13'][x] = data['rows'][0]['elements'][0]['distance']['text']
        addresses['drive_dur_13'][x] = data['rows'][0]['elements'][0]['duration']['text']
        addresses['drive_dur_in_traffic_13'][x] = data['rows'][0]['elements'][0]['duration_in_traffic']['text']       

    except Exception as e:
        addresses['drive_notes_13'][x] = "Unexpected error occurred."
        print("Unexpected error occurred.", e )
        b.beep() # beep once for errors

    # save results, reopen file
    addresses.to_csv('testing_results.csv', index=False)
    addresses = pd.read_csv("testing_results.csv")     

    #dt 14, driving
    print("Calculating... Driving @ DT14!")

    try:
          
        dt = 1614121200 #dt_14 = Tuesday, Feb 23, 2021 6:00:00 PM local time, according to https://www.epochconverter.com/        
        url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'
        url = str(url) + 'mode=driving' + '&origins=' + str(start) + '&destinations=' + str(end) + '&units=imperial' + '&traffic_model=pessimistic' + '&departure_time=' + str(dt) + '&key=' + str(api_key)
        r = requests.get(url)
        data = r.json()
        print(url)        
        
        addresses['dep_time_14'][x] = str(pendulum.from_timestamp(dt))
        addresses['drive_arr_time_14'][x] = str(pendulum.from_timestamp((dt) + (data['rows'][0]['elements'][0]['duration']['value'])))
        addresses['drive_dis_14'][x] = data['rows'][0]['elements'][0]['distance']['text']
        addresses['drive_dur_14'][x] = data['rows'][0]['elements'][0]['duration']['text']
        addresses['drive_dur_in_traffic_14'][x] = data['rows'][0]['elements'][0]['duration_in_traffic']['text']       

    except Exception as e:
        addresses['drive_notes_14'][x] = "Unexpected error occurred."
        print("Unexpected error occurred.", e )
        b.beep() # beep once for errors

    # save results, reopen file
    addresses.to_csv('testing_results.csv', index=False)
    addresses = pd.read_csv("testing_results.csv")     

print ("All Done!")
# beep twice when done 
time.sleep(2)
b.beep(frequency=600, secs=0.1, blocking=True)
time.sleep(1)
b.beep(frequency=600, secs=0.1, blocking=True)

# save results, reopen file
addresses.to_csv('testing_results.csv', index=False)
addresses = pd.read_csv("testing_results.csv")
